# %% [markdown]
# # Experiments with Machine Learning

# %% [markdown]
# **APPROACH:** Predict the price using Machine Learning models, then decide to go long or short.

# %% [markdown]
# First, import necessary libraries

# %%
import pandas as pd 
import yfinance as yf
import math
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score, accuracy_score
from backtesting import Backtest
from business_logic.decision_making.data_prepration import get_OHLC_df, label_OHLC_df, split_train_test, prepare_data_train_model
from business_logic.decision_making.strategies.BinaryClassificationStrategy import BinaryClassificationStrategy
from business_logic.models.portfolio import Portfolio
from business_logic.models.stock import Stock
from enums import Position
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Prepare data
# 3-year data from 2017-2019, and test with data of 2020 and the first half of 2021

# %%
aapl = yf.Ticker('AAPL')
orig_data = aapl.history(start='2018-04-02', end='2021-03-31') 
orig_data.shape
# Out:
# (755, 7)

# %%
orig_data.index
# Out:
# DatetimeIndex(['2018-04-02', '2018-04-03', '2018-04-04', '2018-04-05',
#                '2018-04-06', '2018-04-09', '2018-04-10', '2018-04-11',
#                '2018-04-12', '2018-04-13',
#                ...
#                '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-22',
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-29', '2021-03-30'],
#               dtype='datetime64[ns]', name='Date', length=755, freq=None)

# %% [markdown]
# As can be seen from above, the data fetched from Yahoo Finance is a Dataframe, indexed and sorted by date, which is very convenient. The next step is to split the data into train and test set:

# %%
data = get_OHLC_df(orig_data)
data = label_OHLC_df(data, 2)
data
# Out:
#                   Open        High         Low  Close     Volume
# Date
# 2018-04-04   39.768909   41.488656   39.742377    1.0  138422000
# 2018-04-05   41.626139   42.024116   41.505539    1.0  107732800
# 2018-04-06   41.237811   41.602020   40.569688   -1.0  140021200
# 2018-04-09   40.974904   41.749151   40.967668   -1.0  116070800
# 2018-04-10   41.727450   41.968650   41.372887    1.0  113634400
# ...                ...         ...         ...    ...        ...
# 2021-03-24  122.820000  122.900002  120.070000   -1.0   88530500
# 2021-03-25  119.540001  121.660004  119.000000   -1.0   98844700
# 2021-03-26  120.349998  121.480003  118.919998    1.0   93958900
# 2021-03-29  121.650002  122.580002  120.730003    1.0   80819200
# 2021-03-30  120.110001  120.400002  118.860001   -1.0   85671900
#
# [753 rows x 5 columns]

# %%
data.Close.unique()
# Out:
# array([ 1., -1.])

# %%
split_date = np.datetime64('2020-03-31')
X_train, X_test, y_train, y_test = split_train_test(data, split_date)

# %% [markdown]
# ## Build models and test their performance

# %% [markdown]
# First, I will create a Random Forest Classifier to predict if the price will go up or down. My strategy will then decide to go long or short accordingly. For experimenting, I dedcided to create a classifier with default values.

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
f1_score(y_test, y_pred)
# Out:
# 0.6168224299065421

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5119047619047619

# %%
class TwoClassRandomForestStrategy(BinaryClassificationStrategy):
    price_delta = .004

    def init(self):
        self.clf = rfc

    def next(self):
        row = self.data.df.iloc[-1:]
        X = row[['Open', 'High', 'Low', 'Volume']]
        pred = self.clf.predict(X)[0]

        self.decide_trade(pred)

        # if position has been hold for more than 2 days => set stop-loss to be more aggressive
        current_time = self.data.index[-1]
        high, low = self.data.High, self.data.Low
        for trade in self.trades:
            if current_time - trade.entry_time > pd.Timedelta('2 days'):
                if trade.is_long:
                    trade.sl = max(trade.sl, low)
                else:
                    trade.sl = min(trade.sl, high)

# %%
test_data = orig_data[orig_data.index > split_date]
bt = Backtest(test_data, TwoClassRandomForestStrategy, commission=.0002, margin=.05)
bt.run()
# Out:
# Start                     2020-04-01 00:00:00
# End                       2021-03-30 00:00:00
# Duration                    363 days 00:00:00
# Exposure Time [%]                   99.203187
# Equity Final [$]                   397.524608
# Equity Peak [$]                       10000.0
# Return [%]                         -96.024754
# Buy & Hold Return [%]              100.621644
# Return (Ann.) [%]                  -96.075505
# Volatility (Ann.) [%]                1.585817
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -96.024754
# Avg. Drawdown [%]                  -96.024754
# Max. Drawdown Duration      362 days 00:00:00
# Avg. Drawdown Duration      362 days 00:00:00
# # Trades                                  250
# Win Rate [%]                              6.0
# Best Trade [%]                        0.58093
# Worst Trade [%]                     -3.204015
# Avg. Trade [%]                      -0.318216
# Max. Trade Duration           0 days 00:00:00
# Avg. Trade Duration           0 days 00:00:00
# Profit Factor                        0.044853
# Expectancy [%]                      -0.316332
# SQN                                 -6.274569
# _strategy                 TwoClassRandomFo...
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# In the first attempt, this model lost us almost all of our money. This is understandable because this model uses only default values for hyperparameters, which results in only about 50% accuracy. This will need a lot of fine-tuning.
# Also, the current strategy is very sensitive to price changes because even the slightest change is classified with either up or down. Therefore, if we are going long and the price experiences a small hiccup but the upward trend remains, our bot would just sell all the shares because of that hiccup.

# %% [markdown]
# ## Save to Mongo DB

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), '..')))
from database.mongo_client import get_mongo_db_conn
from business_logic.model_crud import save_model_to_mongo
import pymongo
import time
import pickle

# %% [markdown]
# save_model_to_mongo(rfc, "RandomForestDefault")

# %% [markdown]
# # 3-class labelled data

# %%
data = get_OHLC_df(orig_data)
data = label_OHLC_df(data, 2, small_change_threshold=0.004)
data
# Out:
#                   Open        High         Low  Close     Volume
# Date
# 2018-04-04   39.768909   41.488656   39.742377    1.0  138422000
# 2018-04-05   41.626139   42.024116   41.505539    1.0  107732800
# 2018-04-06   41.237811   41.602020   40.569688   -1.0  140021200
# 2018-04-09   40.974904   41.749151   40.967668   -1.0  116070800
# 2018-04-10   41.727450   41.968650   41.372887    1.0  113634400
# ...                ...         ...         ...    ...        ...
# 2021-03-24  122.820000  122.900002  120.070000   -1.0   88530500
# 2021-03-25  119.540001  121.660004  119.000000   -1.0   98844700
# 2021-03-26  120.349998  121.480003  118.919998    1.0   93958900
# 2021-03-29  121.650002  122.580002  120.730003    1.0   80819200
# 2021-03-30  120.110001  120.400002  118.860001   -1.0   85671900
#
# [753 rows x 5 columns]

# %%
data.Close.value_counts()
# Out:
#  1.0    437
# -1.0    257
#  0.0     59
# Name: Close, dtype: int64

# %% [markdown]
# Dataset is a bit skewed, so accuracy_score shouldn't be considered very seriously.

# %%
X_train, X_test, y_train, y_test = split_train_test(data, split_date)

# %%
class ThreeClassRandomForestStrategy(BinaryClassificationStrategy):
    def init(self):
        self.clf = RandomForestClassifier()
        self.prepare_model(self.clf)

    def next(self):
        print(self.position)
        if self.data.df.index[-1] < self.split_date:
            return

        row = self.data.df.iloc[-1:]
        X = row[['Open', 'High', 'Low', 'Volume']]
        pred = self.clf.predict(X)[0]
        # print(f'Date: {str(row.index[0])} -- Pred: {pred} -- Actual: {row.Close.values[0]}')
        self.decide_trade(pred)

bt = Backtest(orig_data, ThreeClassRandomForestStrategy, commission=.0002, margin=.05)
stats = bt.run()
# Out:
# f1 score: 0.3243237807943691
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>
# <Position: 0 (0 trades)>

# %%
stats
# Out:
# Start                     2018-04-02 00:00:00
# End                       2021-03-30 00:00:00
# Duration                   1093 days 00:00:00
# Exposure Time [%]                   32.715232
# Equity Final [$]                   386.938765
# Equity Peak [$]                       10000.0
# Return [%]                         -96.130612
# Buy & Hold Return [%]              198.235923
# Return (Ann.) [%]                  -66.225376
# Volatility (Ann.) [%]                8.604834
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -96.130612
# Avg. Drawdown [%]                  -96.130612
# Max. Drawdown Duration      364 days 00:00:00
# Avg. Drawdown Duration      364 days 00:00:00
# # Trades                                  248
# Win Rate [%]                         6.048387
# Best Trade [%]                        0.58093
# Worst Trade [%]                     -3.483085
# Avg. Trade [%]                      -0.323334
# Max. Trade Duration           0 days 00:00:00
# Avg. Trade Duration           0 days 00:00:00
# Profit Factor                        0.044538
# Expectancy [%]                      -0.321245
# SQN                                 -4.983831
# _strategy                 ThreeClassRandom...
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
stat_df = stats['_trades']
stat_df
# Out:
#      Size  EntryBar  ExitBar  EntryPrice   ExitPrice          PnL  ReturnPct  \
# 0    -654       504      504   61.138760   61.150990    -7.998549  -0.000200
# 1     670       505      505   59.634753   59.525183   -73.411891  -0.001837
# 2     658       506      506   60.245149   60.233102    -7.926676  -0.000200
# 3    -637       507      507   62.230069   62.242517    -7.929697  -0.000200
# 4     589       508      508   67.192698   64.852319 -1378.483243  -0.034831
# ..    ...       ...      ...         ...         ...          ...        ...
# 243   -13       751      751  119.516093  120.570356   -13.705424  -0.008821
# 244    13       752      752  120.374068  120.107636    -3.463618  -0.002213
# 245   -12       753      753  121.625672  121.694839    -0.830011  -0.000569
# 246   -13       754      754  120.085979  120.110001    -0.312286  -0.000200
# 247   -13       754      754  120.085979  120.379602    -3.817098  -0.002445
#
#      EntryTime   ExitTime Duration
# 0   2020-04-01 2020-04-01   0 days
# 1   2020-04-02 2020-04-02   0 days
# 2   2020-04-03 2020-04-03   0 days
# 3   2020-04-06 2020-04-06   0 days
# 4   2020-04-07 2020-04-07   0 days
# ..         ...        ...      ...
# 243 2021-03-25 2021-03-25   0 days
# 244 2021-03-26 2021-03-26   0 days
# 245 2021-03-29 2021-03-29   0 days
# 246 2021-03-30 2021-03-30   0 days
# 247 2021-03-30 2021-03-30   0 days
#
# [248 rows x 10 columns]

# %%
portfolio = Portfolio()
symbol = 'AAPL'
split_date = np.datetime64('2020-03-31')

clf = RandomForestClassifier()
prepare_data_train_model(clf, orig_data, split_date)

for index, row in orig_data.iterrows():
    X = [row[['Open', 'High', 'Low', 'Volume']]]
    prediction = clf.predict(X)
    stock = portfolio.get_stock(symbol)
    if stock is None:
        current_price = row['Close']
        time = str(row.index[0])
        num_shares = math.floor(portfolio.max_per_stock/current_price)
        stock = None
        if prediction == 1:
            stock = Stock(symbol, current_price, num_shares, time, Position.IS_LONG, is_testing = True)
            portfolio.add_stock(stock)            
        elif prediction == -1:
            stock = Stock(symbol, current_price, -num_shares, time, Position.IS_SHORT, is_testing = True)
            portfolio.add_stock(stock)
        print(f"Pred: {prediction} -- Added stock: {str(stock)} -- Total balance: {portfolio.balance}")
    else:
        if (prediction == 1 and stock.position == Position.IS_SHORT) or (prediction == -1 and stock.position == Position.IS_LONG):
            portfolio.drop_stock(stock.symbol)
            print(f"Pred: {prediction} -- Dropped stock: {str(stock)} -- Total balance: {portfolio.balance}")
        

portfolio.drop_stock(symbol) # sell all shares by the end to see the total return
print(portfolio.balance)
# Out:
# Pred: [-1.] -- Added stock: AAPL, 40.20307159423828, -19 -- Total balance: 4763.858360290527
# Pred: [1.] -- Dropped stock: AAPL, 40.20307159423828, -19 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 41.39217758178711, 19 -- Total balance: 3213.548625946045
# Pred: [-1.] -- Dropped stock: AAPL, 41.39217758178711, 19 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 41.015907287597656, -19 -- Total balance: 4779.3022384643555
# Pred: [1.] -- Dropped stock: AAPL, 41.015907287597656, -19 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 41.592369079589844, 19 -- Total balance: 3209.744987487793
# Pred: [-1.] -- Dropped stock: AAPL, 41.592369079589844, 19 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 39.97152328491211, -20 -- Total balance: 4799.430465698242
# Pred: [1.] -- Dropped stock: AAPL, 39.97152328491211, -20 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 39.15144348144531, -20 -- Total balance: 4783.028869628906
# Pred: [1.] -- Dropped stock: AAPL, 39.15144348144531, -20 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 40.78676986694336, 19 -- Total balance: 3225.051372528076
# Pred: [-1.] -- Dropped stock: AAPL, 40.78676986694336, 19 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 45.1425666809082, -17 -- Total balance: 4767.423633575439
# Pred: [1.] -- Dropped stock: AAPL, 45.1425666809082, -17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 45.27573776245117, 17 -- Total balance: 3230.31245803833
# Pred: [-1.] -- Dropped stock: AAPL, 45.27573776245117, 17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 45.43070602416992, 17 -- Total balance: 3227.6779975891113
# Pred: [-1.] -- Dropped stock: AAPL, 45.43070602416992, 17 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 45.24667739868164, -17 -- Total balance: 4769.193515777588
# Pred: [1.] -- Dropped stock: AAPL, 45.24667739868164, -17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 46.4476432800293, 17 -- Total balance: 3210.390064239502
# Pred: [-1.] -- Dropped stock: AAPL, 46.4476432800293, 17 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 46.302371978759766, -17 -- Total balance: 4787.140323638916
# Pred: [1.] -- Dropped stock: AAPL, 46.302371978759766, -17 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 46.19824981689453, -17 -- Total balance: 4785.370246887207
# Pred: [1.] -- Dropped stock: AAPL, 46.19824981689453, -17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 44.91497039794922, 17 -- Total balance: 3236.4455032348633
# Pred: [-1.] -- Dropped stock: AAPL, 44.91497039794922, 17 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 44.8907470703125, -17 -- Total balance: 4763.1427001953125
# Pred: [1.] -- Dropped stock: AAPL, 44.8907470703125, -17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 46.14497756958008, 17 -- Total balance: 3215.5353813171387
# Pred: [-1.] -- Dropped stock: AAPL, 46.14497756958008, 17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 46.25394058227539, 17 -- Total balance: 3213.6830101013184
# Pred: [-1.] -- Dropped stock: AAPL, 46.25394058227539, 17 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 45.982749938964844, -17 -- Total balance: 4781.706748962402
# Pred: [1.] -- Dropped stock: AAPL, 45.982749938964844, -17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 50.215171813964844, 15 -- Total balance: 3246.7724227905273
# Pred: [-1.] -- Dropped stock: AAPL, 50.215171813964844, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 50.181278228759766, -15 -- Total balance: 4752.7191734313965
# Pred: [1.] -- Dropped stock: AAPL, 50.181278228759766, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 50.425296783447266, 15 -- Total balance: 3243.620548248291
# Pred: [-1.] -- Dropped stock: AAPL, 50.425296783447266, 15 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 52.359405517578125, 15 -- Total balance: 3214.608917236328
# Pred: [-1.] -- Dropped stock: AAPL, 52.359405517578125, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 53.771114349365234, -14 -- Total balance: 4752.795600891113
# Pred: [1.] -- Dropped stock: AAPL, 53.771114349365234, -14 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 53.71522903442383, 14 -- Total balance: 3247.9867935180664
# Pred: [-1.] -- Dropped stock: AAPL, 53.71522903442383, 14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 53.02759552001953, -15 -- Total balance: 4795.413932800293
# Pred: [1.] -- Dropped stock: AAPL, 53.02759552001953, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 53.462528228759766, 14 -- Total balance: 3251.5246047973633
# Pred: [-1.] -- Dropped stock: AAPL, 53.462528228759766, 14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 54.49761962890625, -14 -- Total balance: 4762.9666748046875
# Pred: [1.] -- Dropped stock: AAPL, 54.49761962890625, -14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 52.570804595947266, -15 -- Total balance: 4788.562068939209
# Pred: [1.] -- Dropped stock: AAPL, 52.570804595947266, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 52.813777923583984, 15 -- Total balance: 3207.7933311462402
# Pred: [-1.] -- Dropped stock: AAPL, 52.813777923583984, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 53.28758239746094, -15 -- Total balance: 4799.313735961914
# Pred: [1.] -- Dropped stock: AAPL, 53.28758239746094, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 54.118568420410156, 14 -- Total balance: 3242.340042114258
# Pred: [-1.] -- Dropped stock: AAPL, 54.118568420410156, 14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 53.40664291381836, -14 -- Total balance: 4747.693000793457
# Pred: [1.] -- Dropped stock: AAPL, 53.40664291381836, -14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 51.569732666015625, -15 -- Total balance: 4773.545989990234
# Pred: [1.] -- Dropped stock: AAPL, 51.569732666015625, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 53.99465560913086, 14 -- Total balance: 3244.074821472168
# Pred: [-1.] -- Dropped stock: AAPL, 53.99465560913086, 14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 48.98200225830078, -16 -- Total balance: 4783.7120361328125
# Pred: [1.] -- Dropped stock: AAPL, 48.98200225830078, -16 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 50.83531951904297, 15 -- Total balance: 3237.4702072143555
# Pred: [-1.] -- Dropped stock: AAPL, 50.83531951904297, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 47.34372329711914, -16 -- Total balance: 4757.499572753906
# Pred: [1.] -- Dropped stock: AAPL, 47.34372329711914, -16 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 45.31753158569336, -17 -- Total balance: 4770.398036956787
# Pred: [1.] -- Dropped stock: AAPL, 45.31753158569336, -17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 44.11790466308594, 18 -- Total balance: 3205.877716064453
# Pred: [-1.] -- Dropped stock: AAPL, 44.11790466308594, 18 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 45.06394958496094, 17 -- Total balance: 3233.912857055664
# Pred: [-1.] -- Dropped stock: AAPL, 45.06394958496094, 17 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 42.60131072998047, -18 -- Total balance: 4766.823593139648
# Pred: [1.] -- Dropped stock: AAPL, 42.60131072998047, -18 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 41.68208312988281, 19 -- Total balance: 3208.0404205322266
# Pred: [-1.] -- Dropped stock: AAPL, 41.68208312988281, 19 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 39.972862243652344, -20 -- Total balance: 4799.457244873047
# Pred: [1.] -- Dropped stock: AAPL, 39.972862243652344, -20 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 39.229183197021484, -20 -- Total balance: 4784.58366394043
# Pred: [1.] -- Dropped stock: AAPL, 39.229183197021484, -20 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 38.073455810546875, 21 -- Total balance: 3200.4574279785156
# Pred: [-1.] -- Dropped stock: AAPL, 38.073455810546875, 21 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 38.46113967895508, 20 -- Total balance: 3230.7772064208984
# Pred: [-1.] -- Dropped stock: AAPL, 38.46113967895508, 20 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 36.149662017822266, -22 -- Total balance: 4795.29256439209
# Pred: [1.] -- Dropped stock: AAPL, 36.149662017822266, -22 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 36.75679397583008, 21 -- Total balance: 3228.1073265075684
# Pred: [-1.] -- Dropped stock: AAPL, 36.75679397583008, 21 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 36.57392120361328, -21 -- Total balance: 4768.052345275879
# Pred: [1.] -- Dropped stock: AAPL, 36.57392120361328, -21 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 37.77842330932617, 21 -- Total balance: 3206.6531105041504
# Pred: [-1.] -- Dropped stock: AAPL, 37.77842330932617, 21 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 37.52972412109375, -21 -- Total balance: 4788.124206542969
# Pred: [1.] -- Dropped stock: AAPL, 37.52972412109375, -21 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 38.11002731323242, 20 -- Total balance: 3237.7994537353516
# Pred: [-1.] -- Dropped stock: AAPL, 38.11002731323242, 20 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 40.292266845703125, 19 -- Total balance: 3234.4469299316406
# Pred: [-1.] -- Dropped stock: AAPL, 40.292266845703125, 19 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 41.728614807128906, -19 -- Total balance: 4792.843681335449
# Pred: [1.] -- Dropped stock: AAPL, 41.728614807128906, -19 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 41.67229461669922, 19 -- Total balance: 3208.226402282715
# Pred: [-1.] -- Dropped stock: AAPL, 41.67229461669922, 19 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 42.84523391723633, 18 -- Total balance: 3228.785789489746
# Pred: [-1.] -- Dropped stock: AAPL, 42.84523391723633, 18 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 42.24039840698242, -18 -- Total balance: 4760.327171325684
# Pred: [1.] -- Dropped stock: AAPL, 42.24039840698242, -18 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 44.299774169921875, 18 -- Total balance: 3202.6040649414062
# Pred: [-1.] -- Dropped stock: AAPL, 44.299774169921875, 18 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 45.739620208740234, -17 -- Total balance: 4777.573543548584
# Pred: [1.] -- Dropped stock: AAPL, 45.739620208740234, -17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 46.5134162902832, 17 -- Total balance: 3209.2719230651855
# Pred: [-1.] -- Dropped stock: AAPL, 46.5134162902832, 17 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 48.78582000732422, 16 -- Total balance: 3219.4268798828125
# Pred: [-1.] -- Dropped stock: AAPL, 48.78582000732422, 16 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 50.02732467651367, -15 -- Total balance: 4750.409870147705
# Pred: [1.] -- Dropped stock: AAPL, 50.02732467651367, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 51.21495056152344, 15 -- Total balance: 3231.7757415771484
# Pred: [-1.] -- Dropped stock: AAPL, 51.21495056152344, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 49.68449783325195, -16 -- Total balance: 4794.951965332031
# Pred: [1.] -- Dropped stock: AAPL, 49.68449783325195, -16 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 46.724491119384766, 17 -- Total balance: 3205.683650970459
# Pred: [-1.] -- Dropped stock: AAPL, 46.724491119384766, 17 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 45.006248474121094, -17 -- Total balance: 4765.106224060059
# Pred: [1.] -- Dropped stock: AAPL, 45.006248474121094, -17 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 43.03481674194336, -18 -- Total balance: 4774.6267013549805
# Pred: [1.] -- Dropped stock: AAPL, 43.03481674194336, -18 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 44.87104415893555, 17 -- Total balance: 3237.1922492980957
# Pred: [-1.] -- Dropped stock: AAPL, 44.87104415893555, 17 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 48.78196716308594, 16 -- Total balance: 3219.488525390625
# Pred: [-1.] -- Dropped stock: AAPL, 48.78196716308594, 16 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 48.07402038574219, -16 -- Total balance: 4769.184326171875
# Pred: [1.] -- Dropped stock: AAPL, 48.07402038574219, -16 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 49.099063873291016, 16 -- Total balance: 3214.4149780273438
# Pred: [-1.] -- Dropped stock: AAPL, 49.099063873291016, 16 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 49.543983459472656, 16 -- Total balance: 3207.2962646484375
# Pred: [-1.] -- Dropped stock: AAPL, 49.543983459472656, 16 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 49.4677848815918, -16 -- Total balance: 4791.484558105469
# Pred: [1.] -- Dropped stock: AAPL, 49.4677848815918, -16 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 49.59315490722656, 16 -- Total balance: 3206.509521484375
# Pred: [-1.] -- Dropped stock: AAPL, 49.59315490722656, 16 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 50.554290771484375, 15 -- Total balance: 3241.6856384277344
# Pred: [-1.] -- Dropped stock: AAPL, 50.554290771484375, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 51.06558609008789, -15 -- Total balance: 4765.983791351318
# Pred: [1.] -- Dropped stock: AAPL, 51.06558609008789, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 51.321231842041016, 15 -- Total balance: 3230.1815223693848
# Pred: [-1.] -- Dropped stock: AAPL, 51.321231842041016, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 47.52585220336914, -16 -- Total balance: 4760.413635253906
# Pred: [1.] -- Dropped stock: AAPL, 47.52585220336914, -16 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 50.00612258911133, 15 -- Total balance: 3249.90816116333
# Pred: [-1.] -- Dropped stock: AAPL, 50.00612258911133, 15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 51.563106536865234, 15 -- Total balance: 3226.5534019470215
# Pred: [-1.] -- Dropped stock: AAPL, 51.563106536865234, 15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 50.953636169433594, 15 -- Total balance: 3235.695457458496
# Pred: [-1.] -- Dropped stock: AAPL, 50.953636169433594, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 50.951171875, -15 -- Total balance: 4764.267578125
# Pred: [1.] -- Dropped stock: AAPL, 50.951171875, -15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 50.714290618896484, -15 -- Total balance: 4760.714359283447
# Pred: [1.] -- Dropped stock: AAPL, 50.714290618896484, -15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 51.50635528564453, 15 -- Total balance: 3227.404670715332
# Pred: [-1.] -- Dropped stock: AAPL, 51.50635528564453, 15 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 51.61738967895508, 15 -- Total balance: 3225.739154815674
# Pred: [-1.] -- Dropped stock: AAPL, 51.61738967895508, 15 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 54.26007080078125, -14 -- Total balance: 4759.6409912109375
# Pred: [1.] -- Dropped stock: AAPL, 54.26007080078125, -14 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 54.96823501586914, 14 -- Total balance: 3230.444709777832
# Pred: [-1.] -- Dropped stock: AAPL, 54.96823501586914, 14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 53.96890640258789, -14 -- Total balance: 4755.5646896362305
# Pred: [1.] -- Dropped stock: AAPL, 53.96890640258789, -14 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 54.25760269165039, 14 -- Total balance: 3240.3935623168945
# Pred: [-1.] -- Dropped stock: AAPL, 54.25760269165039, 14 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 55.264339447021484, 14 -- Total balance: 3226.299247741699
# Pred: [-1.] -- Dropped stock: AAPL, 55.264339447021484, 14 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 54.48707962036133, -14 -- Total balance: 4762.819114685059
# Pred: [1.] -- Dropped stock: AAPL, 54.48707962036133, -14 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 56.02679443359375, 14 -- Total balance: 3215.6248779296875
# Pred: [-1.] -- Dropped stock: AAPL, 56.02679443359375, 14 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 56.774444580078125, 14 -- Total balance: 3205.1577758789062
# Pred: [-1.] -- Dropped stock: AAPL, 56.774444580078125, 14 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 58.333900451660156, 13 -- Total balance: 3241.659294128418
# Pred: [-1.] -- Dropped stock: AAPL, 58.333900451660156, 13 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 60.02412414550781, -13 -- Total balance: 4780.313613891602
# Pred: [1.] -- Dropped stock: AAPL, 60.02412414550781, -13 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 63.123294830322266, 12 -- Total balance: 3242.520462036133
# Pred: [-1.] -- Dropped stock: AAPL, 63.123294830322266, 12 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 64.84477233886719, -12 -- Total balance: 4778.137268066406
# Pred: [1.] -- Dropped stock: AAPL, 64.84477233886719, -12 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 65.4090347290039, 12 -- Total balance: 3215.091583251953
# Pred: [-1.] -- Dropped stock: AAPL, 65.4090347290039, 12 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 64.21118927001953, -12 -- Total balance: 4770.534271240234
# Pred: [1.] -- Dropped stock: AAPL, 64.21118927001953, -12 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 66.9979248046875, 11 -- Total balance: 3263.0228271484375
# Pred: [-1.] -- Dropped stock: AAPL, 66.9979248046875, 11 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 67.01276397705078, 11 -- Total balance: 3262.8595962524414
# Pred: [-1.] -- Dropped stock: AAPL, 67.01276397705078, 11 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 78.01863098144531, 10 -- Total balance: 3219.813690185547
# Pred: [-1.] -- Dropped stock: AAPL, 78.01863098144531, 10 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 80.27079010009766, 9 -- Total balance: 3277.562889099121
# Pred: [-1.] -- Dropped stock: AAPL, 80.27079010009766, 9 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 76.3901596069336, -10 -- Total balance: 4763.901596069336
# Pred: [1.] -- Dropped stock: AAPL, 76.3901596069336, -10 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 79.55554962158203, 10 -- Total balance: 3204.4445037841797
# Pred: [-1.] -- Dropped stock: AAPL, 79.55554962158203, 10 -- Total balance: 4000.0
# Pred: [0.] -- Added stock: None -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 81.1707992553711, 9 -- Total balance: 3269.46280670166
# Pred: [-1.] -- Dropped stock: AAPL, 81.1707992553711, 9 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 79.13656616210938, -10 -- Total balance: 4791.365661621094
# Pred: [1.] -- Dropped stock: AAPL, 79.13656616210938, -10 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 77.66050720214844, -10 -- Total balance: 4776.605072021484
# Pred: [1.] -- Dropped stock: AAPL, 77.66050720214844, -10 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 71.77363586425781, 11 -- Total balance: 3210.490005493164
# Pred: [-1.] -- Dropped stock: AAPL, 71.77363586425781, 11 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 66.03065490722656, -12 -- Total balance: 4792.367858886719
# Pred: [1.] -- Dropped stock: AAPL, 66.03065490722656, -12 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 61.58015823364258, -12 -- Total balance: 4738.961898803711
# Pred: [1.] -- Dropped stock: AAPL, 61.58015823364258, -12 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 60.08673095703125, -13 -- Total balance: 4781.127502441406
# Pred: [1.] -- Dropped stock: AAPL, 60.08673095703125, -13 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 60.72429275512695, -13 -- Total balance: 4789.41580581665
# Pred: [1.] -- Dropped stock: AAPL, 60.72429275512695, -13 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 60.90787124633789, 13 -- Total balance: 3208.1976737976074
# Pred: [-1.] -- Dropped stock: AAPL, 60.90787124633789, 13 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 63.08350372314453, 12 -- Total balance: 3242.9979553222656
# Pred: [-1.] -- Dropped stock: AAPL, 63.08350372314453, 12 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 65.1127700805664, 12 -- Total balance: 3218.646759033203
# Pred: [-1.] -- Dropped stock: AAPL, 65.1127700805664, 12 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 66.4821548461914, 12 -- Total balance: 3202.214141845703
# Pred: [-1.] -- Dropped stock: AAPL, 66.4821548461914, 12 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 70.56053924560547, 11 -- Total balance: 3223.83406829834
# Pred: [-1.] -- Dropped stock: AAPL, 70.56053924560547, 11 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 68.6999740600586, 11 -- Total balance: 3244.3002853393555
# Pred: [-1.] -- Dropped stock: AAPL, 68.6999740600586, 11 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 72.72626495361328, 11 -- Total balance: 3200.011085510254
# Pred: [-1.] -- Dropped stock: AAPL, 72.72626495361328, 11 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 76.52749633789062, -10 -- Total balance: 4765.274963378906
# Pred: [1.] -- Dropped stock: AAPL, 76.52749633789062, -10 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 78.3458480834961, 10 -- Total balance: 3216.541519165039
# Pred: [-1.] -- Dropped stock: AAPL, 78.3458480834961, 10 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 80.87313079833984, 9 -- Total balance: 3272.1418228149414
# Pred: [-1.] -- Dropped stock: AAPL, 80.87313079833984, 9 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 82.46015167236328, 9 -- Total balance: 3257.8586349487305
# Pred: [-1.] -- Dropped stock: AAPL, 82.46015167236328, 9 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 94.99955749511719, 8 -- Total balance: 3240.0035400390625
# Pred: [-1.] -- Dropped stock: AAPL, 94.99955749511719, 8 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 97.86514282226562, -8 -- Total balance: 4782.921142578125
# Pred: [1.] -- Dropped stock: AAPL, 97.86514282226562, -8 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 96.78556823730469, -8 -- Total balance: 4774.2845458984375
# Pred: [1.] -- Dropped stock: AAPL, 96.78556823730469, -8 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 92.15138244628906, 8 -- Total balance: 3262.7889404296875
# Pred: [-1.] -- Dropped stock: AAPL, 92.15138244628906, 8 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 95.70849609375, 8 -- Total balance: 3234.33203125
# Pred: [-1.] -- Dropped stock: AAPL, 95.70849609375, 8 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 116.59431457519531, 6 -- Total balance: 3300.434112548828
# Pred: [-1.] -- Dropped stock: AAPL, 116.59431457519531, 6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 115.37823486328125, 6 -- Total balance: 3307.7305908203125
# Pred: [-1.] -- Dropped stock: AAPL, 115.37823486328125, 6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 114.68048858642578, 6 -- Total balance: 3311.9170684814453
# Pred: [-1.] -- Dropped stock: AAPL, 114.68048858642578, 6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 110.84284973144531, 7 -- Total balance: 3224.100051879883
# Pred: [-1.] -- Dropped stock: AAPL, 110.84284973144531, 7 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 120.1205062866211, -6 -- Total balance: 4720.723037719727
# Pred: [1.] -- Dropped stock: AAPL, 120.1205062866211, -6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 114.99815368652344, 6 -- Total balance: 3310.0110778808594
# Pred: [-1.] -- Dropped stock: AAPL, 114.99815368652344, 6 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 116.41603088378906, -6 -- Total balance: 4698.496185302734
# Pred: [1.] -- Dropped stock: AAPL, 116.41603088378906, -6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 122.53689575195312, 6 -- Total balance: 3264.7786254882812
# Pred: [-1.] -- Dropped stock: AAPL, 122.53689575195312, 6 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 122.7565689086914, -6 -- Total balance: 4736.539413452148
# Pred: [1.] -- Dropped stock: AAPL, 122.7565689086914, -6 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 123.05611419677734, -6 -- Total balance: 4738.336685180664
# Pred: [1.] -- Dropped stock: AAPL, 123.05611419677734, -6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 127.61929321289062, 6 -- Total balance: 3234.2842407226562
# Pred: [-1.] -- Dropped stock: AAPL, 127.61929321289062, 6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 126.47101593017578, 6 -- Total balance: 3241.1739044189453
# Pred: [-1.] -- Dropped stock: AAPL, 126.47101593017578, 6 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 131.77308654785156, -6 -- Total balance: 4790.638519287109
# Pred: [1.] -- Dropped stock: AAPL, 131.77308654785156, -6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 134.66876220703125, 5 -- Total balance: 3326.6561889648438
# Pred: [-1.] -- Dropped stock: AAPL, 134.66876220703125, 5 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 130.6947021484375, -6 -- Total balance: 4784.168212890625
# Pred: [1.] -- Dropped stock: AAPL, 130.6947021484375, -6 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 127.63926696777344, -6 -- Total balance: 4765.835601806641
# Pred: [1.] -- Dropped stock: AAPL, 127.63926696777344, -6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 136.665771484375, 5 -- Total balance: 3316.671142578125
# Pred: [-1.] -- Dropped stock: AAPL, 136.665771484375, 5 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 133.7401580810547, -5 -- Total balance: 4668.700790405273
# Pred: [1.] -- Dropped stock: AAPL, 133.7401580810547, -5 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 129.7100067138672, 6 -- Total balance: 3221.739959716797
# Pred: [-1.] -- Dropped stock: AAPL, 129.7100067138672, 6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 126.0, 6 -- Total balance: 3244.0
# Pred: [-1.] -- Dropped stock: AAPL, 126.0, 6 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 123.98999786376953, -6 -- Total balance: 4743.939987182617
# Pred: [1.] -- Dropped stock: AAPL, 123.98999786376953, -6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 124.76000213623047, 6 -- Total balance: 3251.439987182617
# Pred: [-1.] -- Dropped stock: AAPL, 124.76000213623047, 6 -- Total balance: 4000.0
# Pred: [1.] -- Added stock: AAPL, 120.58999633789062, 6 -- Total balance: 3276.4600219726562
# Pred: [-1.] -- Dropped stock: AAPL, 120.58999633789062, 6 -- Total balance: 4000.0
# Pred: [-1.] -- Added stock: AAPL, 121.38999938964844, -6 -- Total balance: 4728.339996337891
# 4000.0
